# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/admin/Downloads/MOOC_Visual.csv')

# %%
df.head(5)
# Out:
#    enrollment_id   startdate     enddate  access  discussion  navigate  \
# 0              1  2014-05-31  2014-06-01      27           0         8
# 1              2  2014-06-04  2014-06-04       7           4         3
# 2              3  2014-06-04  2014-06-08      34           1         6
# 3              4  2014-06-12  2014-06-13      54           4         6
# 4              5  2014-07-01  2014-07-01       0           0         2
#
#    page_close  problem  video  wiki      ...       Saturday  Sunday  Thursday  \
# 0           0       79      0     0      ...              1       1         0
# 1           4        0      3     1      ...              0       0         0
# 2           7        0      9     0      ...              1       1         1
# 3          46       21     31     1      ...              0       0         1
# 4           0        0      0     0      ...              0       0         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72325 entries, 0 to 72324
# Data columns (total 25 columns):
# enrollment_id       72325 non-null int64
# startdate           72325 non-null object
# enddate             72325 non-null object
# access              72325 non-null int64
# discussion          72325 non-null int64
# navigate            72325 non-null int64
# page_close          72325 non-null int64
# problem             72325 non-null int64
# video               72325 non-null int64
# wiki                72325 non-null int64
# proccess_period     72325 non-null float64
# present_days        72325 non-null int64
# effective_time      72325 non-null float64
# Friday              72325 non-null int64
# Monday              72325 non-null int64
# Saturday            72325 non-null int64
# Sunday              72325 non-null int64
# Thursday            72325 non-null int64
# Tuesday             72325 non-null int64
# Wednesday           72325 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['enrollment_id', 'startdate', 'enddate', 'access', 'discussion',
#        'navigate', 'page_close', 'problem', 'video', 'wiki', 'proccess_period',
#        'present_days', 'effective_time', 'Friday', 'Monday', 'Saturday',
#        'Sunday', 'Thursday', 'Tuesday', 'Wednesday', 'holidays',
#        'course_enroll', 'user_enroll', 'course_drop_rate', 'dropout_prob'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# enrollment_id       0
# startdate           0
# enddate             0
# access              0
# discussion          0
# navigate            0
# page_close          0
# problem             0
# video               0
# wiki                0
# proccess_period     0
# present_days        0
# effective_time      0
# Friday              0
# Monday              0
# Saturday            0
# Sunday              0
# Thursday            0
# Tuesday             0
# Wednesday           0
# holidays            0
# course_enroll       0
# user_enroll         0
# course_drop_rate    0
# dropout_prob        0
# dtype: int64

# %%
df.dtypes
# Out:
# enrollment_id         int64
# startdate            object
# enddate              object
# access                int64
# discussion            int64
# navigate              int64
# page_close            int64
# problem               int64
# video                 int64
# wiki                  int64
# proccess_period     float64
# present_days          int64
# effective_time      float64
# Friday                int64
# Monday                int64
# Saturday              int64
# Sunday                int64
# Thursday              int64
# Tuesday               int64
# Wednesday             int64
# holidays              int64
# course_enroll         int64
# user_enroll           int64
# course_drop_rate    float64
# dropout_prob          int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    enrollment_id   startdate     enddate  access  discussion  navigate  \
# 0              1  2014-05-31  2014-06-01      27           0         8
# 1              2  2014-06-04  2014-06-04       7           4         3
# 2              3  2014-06-04  2014-06-08      34           1         6
# 3              4  2014-06-12  2014-06-13      54           4         6
# 4              5  2014-07-01  2014-07-01       0           0         2
#
#    page_close  problem  video  wiki      ...       Saturday  Sunday  Thursday  \
# 0           0       79      0     0      ...              1       1         0
# 1           4        0      3     1      ...              0       0         0
# 2           7        0      9     0      ...              1       1         1
# 3          46       21     31     1      ...              0       0         1
# 4           0        0      0     0      ...              0       0         0
#
# ...

# %%
df.head()
# Out:
#    enrollment_id   startdate     enddate  access  discussion  navigate  \
# 0              1  2014-05-31  2014-06-01      27           0         8
# 1              2  2014-06-04  2014-06-04       7           4         3
# 2              3  2014-06-04  2014-06-08      34           1         6
# 3              4  2014-06-12  2014-06-13      54           4         6
# 4              5  2014-07-01  2014-07-01       0           0         2
#
#    page_close  problem  video  wiki      ...       Saturday  Sunday  Thursday  \
# 0           0       79      0     0      ...              1       1         0
# 1           4        0      3     1      ...              0       0         0
# 2           7        0      9     0      ...              1       1         1
# 3          46       21     31     1      ...              0       0         1
# 4           0        0      0     0      ...              0       0         0
#
# ...

# %%
#coverting the timestamp and extracting the Month,Day_of_month
df['startdate'] = pd.to_datetime(df['startdate'])
df['enddate'] = pd.to_datetime(df['enddate'])

# %%
df['time_period']=(df.enddate - df.startdate).dt.days

# %%
df.head(5)
# Out:
#    enrollment_id  startdate    enddate  access  discussion  navigate  \
# 0              1 2014-05-31 2014-06-01      27           0         8
# 1              2 2014-06-04 2014-06-04       7           4         3
# 2              3 2014-06-04 2014-06-08      34           1         6
# 3              4 2014-06-12 2014-06-13      54           4         6
# 4              5 2014-07-01 2014-07-01       0           0         2
#
#    page_close  problem  video  wiki     ...       Sunday  Thursday  Tuesday  \
# 0           0       79      0     0     ...            1         0        0
# 1           4        0      3     1     ...            0         0        0
# 2           7        0      9     0     ...            1         1        0
# 3          46       21     31     1     ...            0         1        0
# 4           0        0      0     0     ...            0         0        1
#
#    Wednesday  holidays  course_enroll  user_enroll  course_drop_rate  \
# ...

# %%
df.drop(['startdate','enddate'],axis = 1 ,inplace = True)

# %%
df.head(5)
# Out:
#    enrollment_id  access  discussion  navigate  page_close  problem  video  \
# 0              1      27           0         8           0       79      0
# 1              2       7           4         3           4        0      3
# 2              3      34           1         6           7        0      9
# 3              4      54           4         6          46       21     31
# 4              5       0           0         2           0        0      0
#
#    wiki  proccess_period  present_days     ...       Sunday  Thursday  \
# 0     0         1.053588             2     ...            1         0
# 1     1         0.016782             1     ...            0         0
# 2     0         3.975579             5     ...            1         1
# 3     1         0.766829             2     ...            0         1
# 4     0         0.000150             1     ...            0         0
#
#    Tuesday  Wednesday  holidays  course_enroll  user_enroll  course_drop_rate  \
# ...

# %%
#to find the correlation between the variables we use heatmap
fig = plt.figure(figsize = (20,20))
sns.heatmap(df.corr(), annot = True)

# %%
sum(n<0 for n in df['time_period'])
# Out:
# 0

# %%
 sns.countplot(x="dropout_prob", data=df)

# %%
#Data Visualization
df.hist(figsize=(15,15),bins=20,color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F164940>,
# ...
#       dtype=object)

# %%
df['dropout_prob'].value_counts()
# Out:
# 1    57400
# 0    14925
# Name: dropout_prob, dtype: int64

# %%
#20.06% of data is the percentage of the students who will not drop out and 79.36 is the dropout ratio it means the dataset is highly imbalanced hence dataset needs to be balanced
